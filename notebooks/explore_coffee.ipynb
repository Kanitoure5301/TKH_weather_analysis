# %% [markdown]
# # Explore Cofffee
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# %%
# TODO: view first 5 rows of your data
coffee.head()
# Out:
#   country     subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil    Minas Gerais  Arabica       16.2  2002            1500.0
# 1  Brazil  Espirito Santo  Arabica        2.2  2002            1500.0
# 2  Brazil  Espirito Santo  Robusta        7.5  2002            1500.0
# 3  Brazil       Sao Paulo  Arabica        3.2  2002            1500.0
# 4  Brazil          Parana  Arabica        0.5  2002            1500.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         4465.0             495.0            2120.0
# 1         4465.0             495.0            2120.0
# 2         4465.0             495.0            2120.0
# 3         4465.0             495.0            2120.0
# 4         4465.0             495.0            2120.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare
# 0                     2106.0                        3030.0
# 1                     2106.0                        3030.0
# ...

# %%
# TODO: describe your numeric columns
coffee.describe()
# Out:
#         60kgs_bag         year  nonbearing_trees  bearing_trees  \
# count  114.000000   114.000000        109.000000     109.000000
# mean     8.812281  2012.552632        994.495413    5646.926606
# std      9.051550     6.265642        310.338484     372.684151
# min      0.500000  2002.000000        466.000000    4465.000000
# 25%      2.600000  2007.000000        679.000000    5640.000000
# 50%      4.750000  2013.000000       1050.000000    5735.000000
# 75%     12.175000  2018.000000       1185.000000    5810.000000
# max     34.800000  2023.000000       1510.000000    6200.000000
#
#        nonbear_hectares  bearing_hectares  bearing_trees_per_hectare  \
# count        109.000000        109.000000                 109.000000
# mean         298.055046       2146.513761                2639.027523
# std           97.572559         96.699000                 245.497999
# min          148.000000       2010.000000                2106.000000
# ...

# %%
# TODO: display the null values in your dataframe
coffee.isnull()
# Out:
#      country  subdivision   type  60kgs_bag   year  nonbearing_trees  \
# 0      False        False  False      False  False             False
# 1      False        False  False      False  False             False
# 2      False        False  False      False  False             False
# 3      False        False  False      False  False             False
# 4      False        False  False      False  False             False
# ..       ...          ...    ...        ...    ...               ...
# 109    False        False  False      False  False             False
# 110    False        False  False      False  False             False
# 111    False        False  False      False  False             False
# 112    False        False  False      False  False             False
# 113    False        False  False      False  False             False
#
#      bearing_trees  nonbear_hectares  bearing_hectares  \
# 0            False             False             False
# ...

# %%
# TODO: drop your null values
cleaned_coffee=coffee.dropna()

# %%
# TODO: Select only Minas Gerais

mg_coffee= cleaned_coffee[cleaned_coffee['subdivision'] == 'Minas Gerais']

# %%
# TODO: BEGIN YOUR EDA!

# Plotting Bearing trees across the years 
plt.plot(mg_coffee['year'],mg_coffee['bearing_trees'],marker='o', linestyle='-')
plt.title('Bearing Trees Change Throughout Time')
plt.xlabel('Years')
plt.ylabel('Bearing Trees')
plt.show()

# Plotting Bearing Hectares across the years

plt.plot(mg_coffee['year'],mg_coffee['bearing_hectares'],marker='o', linestyle='-')
plt.title('Bearing Hectares Change Throught Time')
plt.xlabel('Years')
plt.ylabel('Bearing Hectares')
plt.show()

# Plotting Count of Coffee Change 

plt.plot(mg_coffee['year'],mg_coffee['60kgs_bag'],marker='o', linestyle='-')
plt.title('60 Kilogram Bags of Coffee Over Time (Minas Gerais)')
plt.xlabel('Years')
plt.ylabel('60 Kilogram Bags (Millions)')
plt.show()

# Plotting Relationship Between Bearing Trees and 60kgs bags

Correlation1= mg_coffee['bearing_trees'].corr(mg_coffee['60kgs_bag'])
plt.scatter(mg_coffee['bearing_trees'], mg_coffee['60kgs_bag'])
plt.title('Bearing Trees Vs 60 kilogram bags')
plt.xlabel('Bearing Trees (Millions)')
plt.ylabel('60 Kilograms Bags (Millions)')
plt.show()
print("Pearson correlations=", Correlation1)

# Graphing he relationship between bearing_hectares and 60kgs_bag


Correlation2= mg_coffee['bearing_hectares'].corr(mg_coffee['60kgs_bag'])
plt.scatter(mg_coffee['bearing_hectares'], mg_coffee['60kgs_bag'])
plt.title('Bearing Hectares Vs 60 kilogram bags')
plt.xlabel('Bearing Hectares (Thousand Hectares)')
plt.ylabel('60 Kilograms Bags (Millions)')
plt.show()
print("Pearson correlations=", Correlation2)
# Out:
# Pearson correlations= 0.6553434210069491
# Pearson correlations= -0.48092018038906487

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# How is bearing trees changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# The number of bearing trees in Minas Gerais has increase significantly over the years. In 2003, there were around 4,500 bearing trees. That number increased to 5,250 in 2004. From 2008 to 2020, the number remained stable. More recently, there was another noticeable increase, reaching a new high of 6,200 bearing trees in 2021. The distribution is slightly skewed and not normal as we don't see a bell curve.

# %% [markdown]
# How is bearing hectares changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# The data demonstrate that bearing hectares in Minas Gerais first increased a peak in 2004 at around 2,350 hectares.  However, from 2006, there was a consistent fall.  By 2017, the amount had dropped to around 2,020 hectares.  The data doesn't follow a normal distribution.  We can observe a declining trendline that is negatively skewed.

# %% [markdown]
# How is the count of million 60kgs bags of coffee changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# The number of million 60kg coffee bags in Minas Gerais has not consistently increased or decreased over time.  Between 2003 and 2016, production fluctuated, with the highest count reaching 27.5 million bags and regular decreases ranging from 15 to 25 million.  In 2017, there was a huge increase of 32.5 million bags.  Since then, from 2017 to 2023, production has stayed pretty stable, never falling below 28.5 million.  The distribution is not normal since there are significant shifts and jumps rather than a consistent pattern.

# %% [markdown]
# What is the relationship between bearing_trees and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# There is a strong positive relationship between the number of bearing trees and the production of 60kg coffee bags.  As the number of bearing trees increases, so does the quantity of 60kg sacks.  A Pearson's correlation coefficient of 0.66 suggests a reasonably strong linear relationship between the two variables.

# %% [markdown]
# What is the relationship between bearing_hectares and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# There is a small negative relationship between bearing hectares and 60kg bags being produced. As the number of bearing hectares increases, the production of 60kgs decreases. A Pearson's correlation coefficient of -0.48 does suggest a small linear relationship between bearing hectares and 60kgs bags.
